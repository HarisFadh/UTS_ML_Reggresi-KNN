# %% [markdown]
# ### Library

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv('counter_strike_2.csv')
data
## memasukkan dan membaca file csv dengan library pada pandas.read / pd.read dan memberikknya nama data tersebut "data"
# Out:
#       time_left  ct_score  t_score       map  bomb_planted  ct_health  \
# 0        175.00       0.0      0.0  de_dust2         False      500.0
# 1        156.03       0.0      0.0  de_dust2         False      500.0
# 2         96.03       0.0      0.0  de_dust2         False      391.0
# 3         76.03       0.0      0.0  de_dust2         False      391.0
# 4        174.97       1.0      0.0  de_dust2         False      500.0
# ...         ...       ...      ...       ...           ...        ...
# 1995      74.90       7.0     10.0  de_train         False      327.0
# 1996      31.23       7.0     10.0  de_train          True      227.0
# 1997      11.23       7.0     10.0  de_train          True      185.0
# 1998     174.91       7.0     11.0  de_train         False      500.0
# 1999     114.90       7.0     11.0  de_train         False      500.0
#
#       t_health  ct_armor  t_armor  ct_money  t_money  ct_helmets  t_helmets  \
# ...

# %%
data.describe()
# Out:
#          time_left     ct_score     t_score    ct_health     t_health  \
# count  2000.000000  2000.000000  2000.00000  2000.000000  2000.000000
# mean     95.630205     6.840000     6.28850   406.170500   402.987500
# std      53.734491     4.233599     4.19059   137.616258   137.699186
# min       0.050000     0.000000     0.00000     2.000000     0.000000
# 25%      54.910000     3.000000     3.00000   315.750000   328.750000
# 50%      94.910000     7.000000     6.00000   500.000000   500.000000
# 75%     156.425000    10.000000    10.00000   500.000000   500.000000
# max     175.000000    15.000000    15.00000   500.000000   500.000000
#
#           ct_armor     t_armor      ct_money       t_money   ct_helmets  \
# count  2000.000000  2000.00000   2000.000000   2000.000000  2000.000000
# mean    306.749000   309.54450   7867.350000  12377.600000     1.821500
# std     172.857221   168.68957   9017.491838  12209.581798     1.774884
# ...

# %%
data.info()

## untuk mengetahu tipe data tiap kolom
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   time_left     2000 non-null   float64
#  1   ct_score      2000 non-null   float64
#  2   t_score       2000 non-null   float64
#  3   map           2000 non-null   object
#  4   bomb_planted  2000 non-null   bool
#  5   ct_health     2000 non-null   float64
#  6   t_health      2000 non-null   float64
#  7   ct_armor      2000 non-null   float64
#  8   t_armor       2000 non-null   float64
#  9   ct_money      2000 non-null   float64
#  10  t_money       2000 non-null   float64
#  11  ct_helmets    2000 non-null   float64
#  12  t_helmets     2000 non-null   float64
#  13  round_winner  2000 non-null   object
# dtypes: bool(1), float64(11), object(2)
# memory usage: 205.2+ KB

# %% [markdown]
# ### Mengubah Values Kolom yang bertipe Data String/Objek menjadi Numerik

# %%
for col in ['map', 'bomb_planted', 'round_winner']:
    label_encoder = LabelEncoder()
    data[col] = label_encoder.fit_transform(data[col])

## dengan label encoder mengubah tipe data string kedalam numerik ada tiga data yang diubah yaitu 2 data tipe objek 
## dan 1 tipe boolean

# %%
data
# Out:
#       time_left  ct_score  t_score  map  bomb_planted  ct_health  t_health  \
# 0        175.00       0.0      0.0    0             0      500.0     500.0
# 1        156.03       0.0      0.0    0             0      500.0     500.0
# 2         96.03       0.0      0.0    0             0      391.0     400.0
# 3         76.03       0.0      0.0    0             0      391.0     400.0
# 4        174.97       1.0      0.0    0             0      500.0     500.0
# ...         ...       ...      ...  ...           ...        ...       ...
# 1995      74.90       7.0     10.0    5             0      327.0     355.0
# 1996      31.23       7.0     10.0    5             1      227.0     152.0
# 1997      11.23       7.0     10.0    5             1      185.0     105.0
# 1998     174.91       7.0     11.0    5             0      500.0     500.0
# 1999     114.90       7.0     11.0    5             0      500.0     500.0
#
#       ct_armor  t_armor  ct_money  t_money  ct_helmets  t_helmets  \
# ...

# %% [markdown]
# ### Memisahkan kolom target dari data

# %%
x = data.drop('round_winner', axis = 1)
y = data['round_winner']

# membagi antara data target(dependen) dan data independen

# %%
x
# Out:
#       time_left  ct_score  t_score  map  bomb_planted  ct_health  t_health  \
# 0        175.00       0.0      0.0    0             0      500.0     500.0
# 1        156.03       0.0      0.0    0             0      500.0     500.0
# 2         96.03       0.0      0.0    0             0      391.0     400.0
# 3         76.03       0.0      0.0    0             0      391.0     400.0
# 4        174.97       1.0      0.0    0             0      500.0     500.0
# ...         ...       ...      ...  ...           ...        ...       ...
# 1995      74.90       7.0     10.0    5             0      327.0     355.0
# 1996      31.23       7.0     10.0    5             1      227.0     152.0
# 1997      11.23       7.0     10.0    5             1      185.0     105.0
# 1998     174.91       7.0     11.0    5             0      500.0     500.0
# 1999     114.90       7.0     11.0    5             0      500.0     500.0
#
#       ct_armor  t_armor  ct_money  t_money  ct_helmets  t_helmets
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1995    1
# 1996    1
# 1997    1
# 1998    1
# 1999    0
# Name: round_winner, Length: 2000, dtype: int32

# %% [markdown]
# ### Splitting Data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

## melakukan pembagian antara data test dan data train yang saya bagi disini 0.2 atau 20%/80% data yang dibagi

# %% [markdown]
# ### Mengetahui Dimensi dari data training

# %%
x_train.shape
# Out:
# (1600, 13)

# %%
x_test.shape
# Out:
# (400, 13)

# %%
y_train.shape
# Out:
# (1600,)

# %%
y_test.shape
# Out:
# (400,)

# %% [markdown]
# ### Modelling KNN

# %%
modelKNN = KNeighborsClassifier(n_neighbors=5)
modelKNN.fit(x_train, y_train)

## Parameter ini menentukan jumlah tetangga terdekat yang akan digunakan oleh algoritma KNN untuk melakukan klasifikasi.
# Out:
# KNeighborsClassifier()

# %%
hasil_prediksi_KNN = modelKNN.predict(x_test)

# %%
print('Akurasi Model: ', accuracy_score(y_test, hasil_prediksi_KNN) * 100)

## didapatkan disini hasil test keakurasian dengan tingkat sekitar 72 ~~ 76 membuktikan bahwa kurang efektif menggunakan KNN
## dengan dataset menentukan siapa yang menang dalam round didalam game counter strike 2 yang diberikan
# Out:
# Akurasi Model:  73.0
